# %% [markdown]
# # I394E managed lanes.
#
# In this notebook we will run through:
#
# 1. Using a configuration file to run lasso
# 2. Setting up a base scenario and applying projects
# 3. Transforming the standard network format to the MetCouncil expected format
# 4. Exporting the network to a shapefile and csvs

# %%
import os
import sys
import yaml

import pandas as pd

from network_wrangler import RoadwayNetwork
from network_wrangler import TransitNetwork
from network_wrangler import ProjectCard
from network_wrangler import Scenario
from network_wrangler import WranglerLogger

from lasso import ModelRoadwayNetwork
from lasso import StandardTransit

# %%
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
# if you don't want to see so much detail, set to logging.INFO or DEBUG
logger.setLevel(logging.DEBUG)

# %% [markdown]
# ## Read a Config File
#
# Let's examine the configuration file and store it as `my_config` variable.
#
# Configuration files are written in YAML and read in as python dictionaries.

# %%
MY_CONFIG_FILE = "C:/projects/met_council_git/data/interim/project_cards/settings/i394_managed_lanes.yaml"

with open(MY_CONFIG_FILE) as f:
        my_config = yaml.safe_load(f)
        
import json
print(json.dumps(my_config, indent=2))

## Alternatively this could be written in the notebook our selected via a notebook GUI
# Out:
# {
#   "base_scenario": {
#     "input_dir": "C:/projects/met_council_git/data/interim/networks/base_network",
#     "shape_file_name": "shape.geojson",
#     "link_file_name": "link.json",
#     "node_file_name": "node.geojson",
#     "transit_directory": "",
#     "validate_network": false
#   },
#   "scenario": {
#     "project_cards_filenames": [
#       "C:/projects/met_council_git/data/interim/project_cards/i394_reversible_managed_lane.yml"
#     ],
#     "card_directory": [],
#     "glob_search": [],
#     "tags": []
#   },
#   "output": {
#     "format": "geojson",
#     "directory": "",
#     "prefix": ""
#   }
# }

# %% [markdown]
# ## Create a Base Scenario
#
# Base scenarios must at the least specify a highway network but can also specify a directory where transit networks can be found.
#
# In this step the highway and transit networks are read in and validated to each other.
#
# In some cases, you may want to override the validation (after reviewing the errors) using the flag: `validate = False`.

# %%
base_wrangler_path = os.path.join(os.path.dirname((os.path.dirname(os.path.abspath('')))),"network_wrangler")
WranglerLogger.info("Base Wrangler Path: {}".format(base_wrangler_path))

base_scenario = Scenario.create_base_scenario(
        my_config["base_scenario"]["shape_file_name"],
        my_config["base_scenario"]["link_file_name"],
        my_config["base_scenario"]["node_file_name"],
        roadway_dir=my_config["base_scenario"]["input_dir"],
        transit_dir=my_config["base_scenario"]["input_dir"],
        validate = False
    )
# Out:
# 2020-05-27 11:32:59, INFO: Base Wrangler Path: D:\network_wrangler
# 2020-05-27 11:32:59, INFO: Reading from following files:
# -C:/projects/met_council_git/data/interim/networks/base_network\link.json
# -C:/projects/met_council_git/data/interim/networks/base_network\node.geojson
# -C:/projects/met_council_git/data/interim/networks/base_network\shape.geojson.
# 2020-05-27 11:38:04, INFO: Read 1134074 links from C:/projects/met_council_git/data/interim/networks/base_network\link.json
# 2020-05-27 11:38:04, INFO: Read 354346 nodes from C:/projects/met_council_git/data/interim/networks/base_network\node.geojson
# 2020-05-27 11:38:04, INFO: Read 1134074 shapes from C:/projects/met_council_git/data/interim/networks/base_network\shape.geojson
# 2020-05-27 11:45:42, INFO: Read in transit feed from: C:/projects/met_council_git/data/interim/networks/base_network
# 2020-05-27 11:45:42, DEBUG: ...agency.txt:
#   agency_id       agency_name                   agency_url  agency_timezone  \
# 0         0     Metro Transit  http://www.metrotransit.org  America/Chicago
# 1         2     Metro Transit  http://www.metrotransit.org  America/Chicago
# 2         3  Minnesota Valley          http://www.mvta.com  America/Chicago
#
#   agency_lang
# 0          EN
# 1          EN
# 2          EN
# 2020-05-27 11:45:42, DEBUG: ...routes.txt:
#   route_id agency_id route_short_name  \
# 0    3-111         0                3
# 1   16-111         2               16
# 2   21-111         0               21
# 3   53-111         0               53
# 4   62-111         0               62
# 5   67-111         0               67
# 6   70-111         0               70
# 7   71-111         0               71
# 8   74-111         0               74
# 9   75-111         0               75
#
#                                      route_long_name route_desc  route_type  \
# 0    U of M - Como Av - Energy Park Dr - Maryland Av        NaN           3
# 1                             University Av - Midway        NaN           3
# 2              Uptown - Lake St - Midway - Selby  Av        NaN           3
# 3          Ltd Stop - Uptown - Lake St - Marshall Av        NaN           3
# 4   Shoreview - Little Canada - Rice St Signal Hills        NaN           3
# 5         W Minnehaha Av - Raymond Sta - Franklin Av        NaN           3
# 6         St Clair Av - W 7th St - Burns Av - Sunray        NaN           3
# 7   Little Canada - Edgerton - Concord - Inver Hills        NaN           3
# 8  46th St - Randolph - W 7th St - E 7th St - Sunray        NaN           3
# 9    Stryker - Robert - Mendota Hts - Lake Cove Apts        NaN           3
#
#                               route_url route_color route_text_color
# 0   http://www.metrotransit.org/route/3         NaN           000000
# 1  http://www.metrotransit.org/route/16         NaN           000000
# 2  http://www.metrotransit.org/route/21         NaN           000000
# 3  http://www.metrotransit.org/route/53         NaN           000000
# 4  http://www.metrotransit.org/route/62         NaN           000000
# 5  http://www.metrotransit.org/route/67         NaN           000000
# 6  http://www.metrotransit.org/route/70         NaN           000000
# 7  http://www.metrotransit.org/route/71         NaN           000000
# 8  http://www.metrotransit.org/route/74         NaN           000000
# 9  http://www.metrotransit.org/route/75         NaN           000000
# 2020-05-27 11:45:42, DEBUG: ...calendar.txt:
# Empty DataFrame
# Columns: [service_id, monday, tuesday, wednesday, thursday, friday, saturday, sunday, start_date, end_date]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing calendar.txt from transit network config because file not found
# 2020-05-27 11:45:42, DEBUG: ...trips.txt:
#   route_id                service_id                            trip_id  \
# 0  452-111  JUN19-MVS-BUS-Weekday-01  14940701-JUN19-MVS-BUS-Weekday-01
# 1    3-111  JUN19-MVS-BUS-Weekday-01  14941148-JUN19-MVS-BUS-Weekday-01
# 2    3-111  JUN19-MVS-BUS-Weekday-01  14941151-JUN19-MVS-BUS-Weekday-01
# 3    3-111  JUN19-MVS-BUS-Weekday-01  14941153-JUN19-MVS-BUS-Weekday-01
# 4    3-111  JUN19-MVS-BUS-Weekday-01  14941163-JUN19-MVS-BUS-Weekday-01
# 5   74-111  JUN19-MVS-BUS-Weekday-01  14941643-JUN19-MVS-BUS-Weekday-01
# 6   74-111  JUN19-MVS-BUS-Weekday-01  14941652-JUN19-MVS-BUS-Weekday-01
# 7  417-111  JUN19-MVS-BUS-Weekday-01  14942968-JUN19-MVS-BUS-Weekday-01
# 8  294-111  JUN19-MVS-BUS-Weekday-01  14943414-JUN19-MVS-BUS-Weekday-01
# 9  294-111  JUN19-MVS-BUS-Weekday-01  14943415-JUN19-MVS-BUS-Weekday-01
#
#                                        trip_headsign  direction_id block_id  \
# 0               Westbound 452  Express / Minneapolis             1     1874
# 1     Eastbound 3B Como Av/St Paul - Depot/Via Front             0     1018
# 2     Westbound 3B Como-Front/Dwtn Mpls/Target Field             1     1017
# 3     Westbound 3B Como-Front/Dwtn Mpls/Target Field             1     1017
# 4     Eastbound 3B Como Av/St Paul - Depot/Via Front             0     1036
# 5          Westbound 74A  Randolph Av / 46St Station             1     1642
# 6          Westbound 74A  Randolph Av / 46St Station             1     1642
# 7          Northbound 417 Ltd Stop/ Dodd Rd/ St Paul             0    31290
# 8                   Westbound 294  Express / St Paul             1     1576
# 9  Eastbound 294 Express/St Crx P&R/Via 4 Front Tech             0     1649
#
#   shape_id  wheelchair_accessible trip_destination trip_short_name  \
# 0  4520004                    1.0              NaN             NaN
# 1    30009                    1.0              NaN             NaN
# 2    30014                    1.0              NaN             NaN
# 3    30014                    1.0              NaN             NaN
# 4    30009                    1.0              NaN             NaN
# 5   740006                    1.0              NaN             NaN
# 6   740006                    1.0              NaN             NaN
# 7  4170001                    1.0              NaN             NaN
# 8  2940002                    1.0              NaN             NaN
# 9  2940004                    1.0              NaN             NaN
#
#   trip_route_name pub_dir_id rm_block_id
# 0             NaN        NaN         NaN
# 1             NaN        NaN         NaN
# 2             NaN        NaN         NaN
# 3             NaN        NaN         NaN
# 4             NaN        NaN         NaN
# 5             NaN        NaN         NaN
# 6             NaN        NaN         NaN
# 7             NaN        NaN         NaN
# 8             NaN        NaN         NaN
# 9             NaN        NaN         NaN
# 2020-05-27 11:45:42, DEBUG: ...calendar_dates.txt:
# Empty DataFrame
# Columns: [service_id, date, exception_type]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing calendar_dates.txt from transit network config because file not found
# 2020-05-27 11:45:42, DEBUG: ...fare_attributes.txt:
# Empty DataFrame
# Columns: [fare_id, price, currency_type, payment_method, transfers]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing fare_attributes.txt from transit network config because file not found
# 2020-05-27 11:45:42, DEBUG: ...fare_rules.txt:
# Empty DataFrame
# Columns: [fare_id]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing fare_rules.txt from transit network config because file not found
# 2020-05-27 11:45:42, DEBUG: ...stops.txt:
#   stop_id stop_code                        stop_name      stop_desc  \
# 0   10119       NaN  St Clair Ave & Stairs to Grotto    Near side W
# 1   10120       NaN           St Clair Ave & Avon St    Near side W
# 2   10121       NaN       St Clair Ave & Victoria St    Near side W
# 3   10123       NaN         St Clair Ave & Milton St    Near side W
# 4   10124       NaN     St Clair Ave & Chatsworth St    Near side W
# 5   10126       NaN         St Clair Ave & Oxford St    Near side W
# 6   10172       NaN        St Clair Ave & Benhill Rd    Near side E
# 7   10174       NaN         St Clair Ave & Milton St    Near side E
# 8   10176       NaN       St Clair Ave & Victoria St  Across from E
# 9   10177       NaN           St Clair Ave & Avon St  Across from E
#
#     stop_lat   stop_lon zone_id  \
# 0  44.934173 -93.131190     NaN
# 1  44.934178 -93.133690     NaN
# 2  44.934186 -93.136243     NaN
# 3  44.934210 -93.138773     NaN
# 4  44.934218 -93.141323     NaN
# 5  44.934215 -93.143884     NaN
# 6  44.934106 -93.143053     NaN
# 7  44.934106 -93.139055     NaN
# 8  44.934084 -93.136517     NaN
# 9  44.934073 -93.133944     NaN
#
#                                             stop_url  location_type  \
# 0  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 1  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 2  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 3  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 4  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 5  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 6  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 7  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 8  http://www.metrotransit.org/NexTripBadge.aspx?...              0
# 9  http://www.metrotransit.org/NexTripBadge.aspx?...              0
#
#    wheelchair_boarding model_node_id osm_node_id  \
# 0                  1.0         46886   187868000
# 1                  1.0         54358   187883263
# 2                  1.0         43004   187860779
# 3                  1.0         57392   187890295
# 4                  1.0         56476   187888280
# 5                  1.0         74731   187936294
# 6                  1.0         74730   187936293
# 7                  1.0         57392   187890295
# 8                  1.0        137734  3071141453
# 9                  1.0         54358   187883263
#
#                           node_ssid parent_station
# 0  e096bcee806f8ee804e223b832b914a4            NaN
# 1  fb83b4f2cd360907befedfaf61081ef2            NaN
# 2  c16292a1f8165c26b71f2743189b7a49            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# 5  e253d08af7eac74b6650133252908472            NaN
# 6  192efcdf1e3bf6912303adcba9c18bbb            NaN
# 7                               NaN            NaN
# 8  49e0f73c301f745ec9dc36a5b752a32e            NaN
# 9  fb83b4f2cd360907befedfaf61081ef2            NaN
# 2020-05-27 11:45:42, DEBUG: ...frequencies.txt:
#                              trip_id  headway_secs  start_time  end_time
# 0  14940701-JUN19-MVS-BUS-Weekday-01          3600     21600.0   32400.0
# 1  14941148-JUN19-MVS-BUS-Weekday-01           830     21600.0   32400.0
# 2  14941151-JUN19-MVS-BUS-Weekday-01           540     21600.0   32400.0
# 3  14941153-JUN19-MVS-BUS-Weekday-01           696     32400.0   54000.0
# 4  14941163-JUN19-MVS-BUS-Weekday-01           830     32400.0   54000.0
# 5  14941643-JUN19-MVS-BUS-Weekday-01           900     21600.0   32400.0
# 6  14941652-JUN19-MVS-BUS-Weekday-01          1200     32400.0   54000.0
# 7  14942968-JUN19-MVS-BUS-Weekday-01          5400     21600.0   32400.0
# 8  14943414-JUN19-MVS-BUS-Weekday-01          2160     21600.0   32400.0
# 9  14943415-JUN19-MVS-BUS-Weekday-01          5400     21600.0   32400.0
# 2020-05-27 11:45:42, DEBUG: ...shapes.txt:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence shape_osm_node_id  \
# 0  4520004     44.923257    -93.067060                 55         507955865
# 1  4520004     44.930632    -93.071166                 56         507951624
# 2  4520004     44.932669    -93.071710                 57         507951633
# 3  4520004     44.939445    -93.075273                 58         507951645
# 4  4520004     44.943056    -93.076998                 59        2548150957
# 5  4520004     44.951951    -93.081687                 60        2291969930
# 6  4520004     44.952673    -93.083884                 61         187872060
# 7  4520004     44.952707    -93.087583                 62         961117649
# 8  4520004     44.954043    -93.089649                 63         961116213
# 9  4520004     44.952407    -93.096553                 64         961086473
#
#   shape_model_node_id
# 0              152495
# 1              151635
# 2              151637
# 3              151641
# 4               23834
# 5              108658
# 6               49113
# 7               19614
# 8               19288
# 9               11354
# 2020-05-27 11:45:42, DEBUG: ...stop_times.txt:
#                              trip_id  arrival_time  departure_time stop_id  \
# 0  14940701-JUN19-MVS-BUS-Weekday-01           0.0             0.0   56107
# 1  14940701-JUN19-MVS-BUS-Weekday-01           0.0             0.0   42823
# 2  14940701-JUN19-MVS-BUS-Weekday-01           0.0             0.0   44061
# 3  14940701-JUN19-MVS-BUS-Weekday-01          60.0            60.0   42822
# 4  14940701-JUN19-MVS-BUS-Weekday-01          60.0            60.0   42821
# 5  14940701-JUN19-MVS-BUS-Weekday-01         120.0           120.0   42820
# 6  14940701-JUN19-MVS-BUS-Weekday-01         120.0           120.0    2719
# 7  14940701-JUN19-MVS-BUS-Weekday-01         120.0           120.0    2720
# 8  14940701-JUN19-MVS-BUS-Weekday-01         180.0           180.0    2721
# 9  14940701-JUN19-MVS-BUS-Weekday-01         180.0           180.0    2722
#
#    stop_sequence  pickup_type drop_off_type stop_distance  timepoint  \
# 0              1            0             0           NaN        NaN
# 1              2            0             0           NaN        NaN
# 2              3            0             0           NaN        NaN
# 3              4            0             0           NaN        NaN
# 4              5            0             0           NaN        NaN
# 5              6            0             0           NaN        NaN
# 6              7            0             0           NaN        NaN
# 7              8            0             0           NaN        NaN
# 8              9            0             0           NaN        NaN
# 9             10            0             0           NaN        NaN
#
#   stop_is_skipped
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 2020-05-27 11:45:42, DEBUG: ...transfers.txt:
# Empty DataFrame
# Columns: [from_stop_id, to_stop_id, transfer_type, min_transfer_time]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing transfers.txt from transit network config because file not found
# 2020-05-27 11:45:42, DEBUG: ...feed_info.txt:
# Empty DataFrame
# Columns: [feed_publisher_name, feed_publisher_url, feed_lang]
# Index: []
# 2020-05-27 11:45:42, INFO: Removing feed_info.txt from transit network config because file not found
# 2020-05-27 11:45:42, WARNING: The following stop_ids from are referenced but missing from stops.txt: [nan, '49642', '56038', '45313', '16093', '10146', '52791', '49641', '7261', '16081', '46955', '19044', '16107', '11002', '10201', '17882', '16966', '56335', '11003', '41061', '15855', '625', '46922', '49660', '2716', '11752', '407', '16894', '53873', '15057', '43022', '10149', '16103', '16855', '15056', '51423', '344', '40954', '320', '16890', '13758', '18809', '53723', '18566', '13630', '16837', '40985', '42195', '18875', '46912', '12901', '659', '41383', '13211', '669', '12898', '2702', '1335', '9713', '13674', '4290', '17040', '50099', '9700', '47529', '270', '42843', '3070', '2284', '10137', '42425', '9705', '56591', '12902', '51784', '15211', '16531', '16988', '56333', '3055', '7643', '2710', '13702', '46900', '929', '340', '7704', '15858', '53435', '56042', '16950', '810', '16964', '16909', '2700', '10200', '49636', '56783', '936', '16080', '19048', '43504', '15216', '46927', '911', '15217', '19035', '2718', '51200', '43815', '2723', '48574', '7258', '10163', '16989', '7507', '51096', '50594', '15869', '16868', '13761', '2731', '7640', '9724', '52062', '51547', '52787', '2443', '13754', '7508', '46911', '2472', '53914', '382', '46908', '2469', '16990', '51116', '16877', '2424', '927', '2711', '18219', '2470', '18236', '43559', '56007', '812', '16888', '7642', '884', '612', '16895', '15130', '56036', '876', '7259', '16865', '16879', '49784', '2733', '18556', '16070', '4287', '46933', '4288', '51448', '51093', '1333', '388', '56332', '2715', '51090', '15801', '1244', '9718', '15798', '42820', '43553', '56041', '13267', '19049', '15860', '16857', '42382', '10140', '13269', '1243', '16901', '16946', '46701', '18308', '16534', '48577', '42845', '15804', '51409', '332', '623', '16558', '49779', '602', '53872', '12915', '7705', '10155', '19047', '7472', '9680', '9702', '2738', '50667', '2452', '15857', '40179', '262', '48728', '9683', '2712', '56337', '16076', '41542', '50116', '56005', '389', '9909', '16886', '15818', '3067', '51132', '16908', '56052', '49635', '13631', '9715', '40974', '50588', '16949', '11754', '54098', '13688', '46920', '15810', '5247', '18695', '56703', '7645', '46699', '40970', '13755', '51449', '18616', '16999', '18563', '49697', '17859', '16926', '9707', '47797', '9709', '49647', '13279', '56035', '13690', '18220', '18302', '400', '15218', '16947', '535', '15811', '13699', '2703', '11711', '7646', '668', '10199', '16851', '1245', '2721', '604', '16882', '17890', '17901', '49780', '808', '49656', '49178', '2280', '49242', '18306', '49694', '11743', '54011', '10138', '42823', '40118', '19032', '16912', '662', '18304', '365', '46936', '7470', '10148', '7635', '49651', '3068', '3054', '922', '3066', '15859', '9723', '48122', '18814', '9726', '10144', '16863', '46700', '51424', '921', '393', '42040', '13692', '56776', '16959', '18665', '17003', '16965', '52790', '13221', '16514', '49422', '15222', '5182', '919', '938', '16836', '2736', '13787', '46901', '16527', '46926', '45314', '19038', '51183', '42032', '12896', '51095', '42036', '14727', '10168', '16532', '16957', '15809', '9691', '16842', '15215', '56107', '426', '874', '2435', '56331', '53121', '56339', '16996', '56043', '7636', '48384', '2707', '2281', '40055', '15131', '7255', '2741', '5167', '15868', '40987', '46898', '402', '16997', '51453', '16559', '385', '7260', '11715', '18810', '50157', '42444', '13704', '7454', '2704', '914', '17870', '16924', '18309', '338', '16880', '2735', '51285', '15054', '7469', '16094', '7287', '11007', '16067', '46958', '1332', '50593', '17864', '13770', '9721', '14735', '56226', '5099', '56001', '49634', '7503', '16513', '2750', '11011', '10228', '3065', '51048', '51493', '13672', '56292', '870', '414', '41059', '56009', '51113', '809', '2722', '7634', '335', '16607', '49657', '15225', '15876', '16098', '15214', '17894', '13624', '7277', '10134', '56021', '56790', '46960', '10131', '52060', '56336', '51184', '924', ' ...
# 2020-05-27 11:45:42, DEBUG: starting ox_graph()
# 2020-05-27 11:45:42, DEBUG: GRAPH NODES: Index(['model_node_id', 'osm_node_id', 'shstReferenceId', 'drive_node',
#        'walk_node', 'bike_node', 'bus_only', 'rail_only', 'geometry', 'x',
#        'y'],
#       dtype='object')
# 2020-05-27 11:45:45, DEBUG: starting ox.gdfs_to_graph()
# 2020-05-27 11:54:14, DEBUG: finished ox.gdfs_to_graph()

# %% [markdown]
# #### Create project cards from projects that are explicitely specified in config

# %%
if len(my_config["scenario"]["project_cards_filenames"]) > 0:
    project_cards_list = [
        ProjectCard.read(filename, validate=False)
        for filename in my_config["scenario"]["project_cards_filenames"]
    ]
else: 
    project_cards_list = []
project_cards_list

# %% [markdown]
# ## Create Scenario
#
# A scenario is constructed with a base scenario and then selecting project cards to be added to that base scenario to create the new scenario.
#
# Projects can be added a variety of ways:
#
#  1. `card_directory` + `tags` will search a directory add project's who's project tags match *at least one of* the tags in the keyword.
#  2. `card_directory` + `glob_search` will search a directory add project's who's file name matches the [glob search text](https://docs.python.org/3/library/glob.html)
#  3. `project_cards_list` is a list of ProjectCard objects
#
# Optionally, you may specify that project card formats are not validated by setting they keyword:
#    `validate = False`
#
# Projects that are not added in the initial scenario development can be added by using the following methods:
#
#  - `add_project_card_from_file()`
#  - `add_project_cards_from_directory()`
#  - `add_project_cards_from_tags`
#
# Or by directly adding the project to the scenario's project attribute by running:
#
# ```python
# my_project = ProjectCard.read(path_to_card)
# my_scenario.projects += my_project
#
# ```

# %%
my_scenario=None

my_scenario = Scenario.create_scenario(
    base_scenario=base_scenario,
    project_cards_list=project_cards_list,
    validate_project_cards=False,
)
# Out:
# 2020-05-27 11:54:14, INFO: Creating Scenario
# 2020-05-27 11:54:14, DEBUG: Adding project cards from List.
# I394E Reversible Lanes

# %% [markdown]
# ### Apply all projects in scenario

# %%
WranglerLogger.info("\nProjects in queue to be applied: \n - {}".format("\n - ".join(my_scenario.get_project_names())))
WranglerLogger.info("\n[Before] Applied Projects: \n - {}".format("\n - ".join(my_scenario.applied_projects)))

my_scenario.apply_all_projects()

WranglerLogger.info("\n[After] Applied Projects: \n - {}".format("\n - ".join(my_scenario.applied_projects)))
# Out:
# 2020-05-27 11:57:22, INFO:
# Projects in queue to be applied:
#  - I394E Reversible Lanes
# 2020-05-27 11:57:22, INFO:
# [Before] Applied Projects:
#  -
# 2020-05-27 11:57:22, DEBUG: Ordered Project Cards: {'i394e reversible lanes': <network_wrangler.projectcard.ProjectCard object at 0x000001CE88F2B188>}
# 2020-05-27 11:57:22, DEBUG: Project Cards: [<network_wrangler.projectcard.ProjectCard object at 0x000001CE88F2B188>]
# 2020-05-27 11:57:22, INFO: Applying I394E Reversible Lanes
# 2020-05-27 11:57:22, INFO: Applying Project to Roadway Network: I394E Reversible Lanes
# 2020-05-27 11:57:22, DEBUG: validating selection
# 2020-05-27 11:57:22, DEBUG: Selection Key: ((model_link_id==394063 or model_link_id==404192 or model_link_id==403006 or model_link_id==402701 or model_link_id==402700 or model_link_id==403289 or model_link_id==382272 or model_link_id==419239 or model_link_id==419238))
# 2020-05-27 11:57:22, DEBUG: Building selection query
# 2020-05-27 11:57:22, DEBUG: Selecting features:
# ((model_link_id==394063 or model_link_id==404192 or model_link_id==403006 or model_link_id==402701 or model_link_id==402700 or model_link_id==403289 or model_link_id==382272 or model_link_id==419239 or model_link_id==419238))
# 2020-05-27 11:57:22, DEBUG: Completed query
# d:\network_wrangler\network_wrangler\roadwaynetwork.py:847: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candidate_links["i"] = 0
# 2020-05-27 11:57:23, INFO:
# [After] Applied Projects:
#  - I394E Reversible Lanes

# %%
#my_scenario.road_net.links_df.info()

# %%
#my_scenario.road_net.links_df[my_scenario.road_net.links_df["segment_id"] == 5]

# %% [markdown]
# # Write out as MetCouncil Model Roadway Network
# Everything above was done in "pure wrangler" rather than lasso.  However, we will need Lasso in order to add the MetCouncil specific variables. You can create a lasso ModelRoadwayNetwork object from the roadway network object and feed it any additional parameters from that `my_config` variable.
#
# You can see that the link variables for this network are the same as the standard roadway network at this point but that will change.
#
# Since this is a GeoDataFrame you can also use build-in Geopandas features to make simple plots based on these variables.

# %%
model_road_net = ModelRoadwayNetwork.from_RoadwayNetwork(
    my_scenario.road_net, parameters=my_config.get("my_parameters", {})
)
# Out:
# 2020-05-27 12:03:43, INFO: Lasso base directory set as: D:\lasso

# %%
#model_road_net.links_df.info()

# %%
#model_road_net.links_df.loc[model_road_net.links_df["HOV"] == "NaN", "HOV"] = "0"

# %%
#model_road_net.links_df[model_road_net.links_df["HOV"] != "0"]

# %%
#model_road_net.nodes_df.info()

# %% [markdown]
# ## Add MetCouncil variables
# At this point, we need to calculate all the variables into what MetCouncil's model is expecting. The method `roadway_standard_to_met_council_network()` broadly does the following:
#
# - creates a parallel managed lane network
# - calculates additional variables based on geography or other variables (i.e. county, assignment group, area type, etc)
# - flattens variables stored as continuous time values and determines their value by time period (i.e. lanes_am)
# - reprojects into MetCouncil's projection

# %%
model_road_net.roadway_standard_to_met_council_network()
# Out:
# 2020-05-27 12:03:43, INFO: Renaming roadway attributes to be consistent with what metcouncil's model is expecting
# 2020-05-27 12:03:43, INFO: Creating managed lane network.
# 2020-05-27 12:03:43, INFO: Creating network with duplicated managed lanes
# d:\network_wrangler\network_wrangler\roadwaynetwork.py:1768: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml_links_df[attr] = ""
# d:\network_wrangler\network_wrangler\roadwaynetwork.py:1762: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml_links_df[gp_attr] = ml_links_df[attr]
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pandas\core\frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# 2020-05-27 12:04:18, INFO: Creating calculated roadway variables.
# 2020-05-27 12:04:18, INFO: Calculating Area Type from Spatial Data and adding as roadway network variable: area_type
# 2020-05-27 12:04:29, DEBUG: Reading Area Type Shapefile D:\lasso\metcouncil_data\area_type\ThriveMSP2040CommunityDesignation.shp
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(4326 != {'init': 'epsg:4326', 'no_defs': True})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# 2020-05-27 12:06:27, DEBUG: Area Type Codes Used: {23: 4, 24: 3, 25: 2, 35: 2, 36: 1, 41: 1, 51: 1, 52: 1, 53: 1, 60: 1}
# 2020-05-27 12:06:27, INFO: Finished Calculating Area Type from Spatial Data into variable: area_type
# 2020-05-27 12:06:30, INFO: Adding roadway network variable for county using a spatial join with: D:\lasso\metcouncil_data\county\cb_2017_us_county_5m.shp
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(4326 != {'init': 'epsg:4326', 'no_defs': True})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# 2020-05-27 12:08:24, INFO: Finished Calculating county variable: county
# 2020-05-27 12:08:28, INFO: Calculating Centroid Connector and adding as roadway network variable: centroidconnect
# 2020-05-27 12:08:28, DEBUG: Calculating Centroid Connectors using highest TAZ number: 3100
# 2020-05-27 12:08:28, INFO: Finished calculating centroid connector variable: centroidconnect
# 2020-05-27 12:08:28, INFO: Calculating MPO as roadway network variable: mpo
# 2020-05-27 12:08:28, DEBUG: MPO Counties: [,1,,, ,3,,, ,4,,, ,5,,, ,6,,, ,7,,, ,2,]
# 2020-05-27 12:08:28, INFO: Finished calculating MPO variable: mpo
# 2020-05-27 12:08:28, INFO: Calculating Assignment Group as network variable: assign_group
# 2020-05-27 12:08:28, DEBUG: Calculating Centroid Connectors
# 2020-05-27 12:08:28, INFO: Centroid Connector Variable 'centroidconnect' already in network. Returning without overwriting.
# 2020-05-27 12:08:28, DEBUG: Reading MRCC / Shared Streets Match CSV
# 2020-05-27 12:08:28, DEBUG: Reading MRCC Shapefile: D:\lasso\metcouncil_data\mrcc\trans_mrcc_centerlines.shp
# 2020-05-27 12:08:36, DEBUG: MRCC GDF Columns
# Index(['LINK_ID', 'ROUTE_SYS', 'ST_CONCAT', 'geometry'], dtype='object')
# 2020-05-27 12:08:36, DEBUG: mrcc shst ref df columns
# Index(['shstReferenceId', 'shstGeometryId', 'pp_link_id', 'score'], dtype='object')
# 2020-05-27 12:08:46, DEBUG: WiDOT GDF Columns
# Index(['OBJECTID', 'WISLR_OVLY', 'SURF_TYCD', 'TRLNS_SURF', 'TRLNS_SU_1',
#        'LSHD_SURF_', 'LEFT_SHLD_', 'RSHD_SURF_', 'RGHT_SHLD_', 'RDWY_OWRST',
#        'RW_INDC', 'RW_WD', 'MEDN_TYCD', 'LEFT_CURB_', 'RGHT_CURB_',
#        'PRKG_TYCD', 'TRLNS_NB', 'WISLR_SFRT', 'SDWK_TYCD', 'HARST_TYCD',
#        'VARST_TYCD', 'RDWY_MAGMT', 'RDWY_MAG_1', 'LOC_WISLR_', 'RWCRT_MILG',
#        'RDWY_CTGY_', 'RDWY_SBCTG', 'AVG_DLY_TR', 'AVG_DLY__1', 'AVG_DLY__2',
#        'RDWY_ACS_T', 'FED_URLC_T', 'FEDUA_TYCD', 'FED_CLSN_T', 'FNCT_CLS_T',
#        'NHS_CLS_TY', 'NHS_RTE_NB', 'HPMS_SMPL_', 'HOV_LANE_T', 'PVMT_IRI_N',
#        'PVMT_IRI_Y', 'ST_LABL_NM', 'ST_PRMY_SY', 'RDWY_LINK_', 'SHC_NTWK_N',
#        'WISLR_PTY_', 'WISLR_PTY1', 'WISLR_CMTY', 'WISLR_CERT', 'DOT_CNTY_C',
#        'LOC_FLKOS_', 'LOC_TLKOS_', 'LINK_OVLY_', 'DIR_INDC', 'OPOS_RDWY_',
#        'INV_YR', 'LOC_WI_CMT', 'MEDN_WD_MS', 'RDWY_SBML_', 'RDWY_GTRST',
#        'RDWY_HTRST', 'RDWY_MNTNR', 'RDWY_OWNR_', 'RDWY_SLRST', 'RDWY_WDRST',
#        'RDWY_WTRST', 'RWCRT_PTY_', 'RDWY_CERT_', 'RWSR_SYS_T', 'RDWY_SURF_',
#        'CSTMS_SFRT', 'RDWY_RTG_D', 'CNTY_PRMY_', 'DSGND_TRK_', 'DSGND_TRK1',
#        'CTFR_INDC', 'FNCT_CLS_C', 'FNCT_CLS_G', 'HPMS_SMPL1', 'WISLR_PT_1',
#        'SEG_WISLR_', 'RWCRT_RTE_', 'ASGD_RTE_I', 'ASGD_RTE_S', 'SFRTG_TYCD',
#        'RTG_SURF_T', 'TRADS_ID', 'PA_WISLR_P', 'WISLR_PT_2', 'PMRC_TYCD',
#        'DOT_RGN_NB', 'FED_SFGRP_', 'TRMT_TYID', 'MNTC_TRMT_', 'MNTC_TRMT1',
#        'MNTC_TRM_1', 'SHAPE_Leng', 'geometry', 'LINK_ID'],
#       dtype='object')
# 2020-05-27 12:09:05, DEBUG: widot shst ref df columns
# 2020-05-27 12:09:05, DEBUG: source ShSt rename_variables_for_dbf columns
# Index(['shstReferenceId', 'shstGeometryId', 'pp_link_id', 'score'], dtype='object')
# 2020-05-27 12:09:05, DEBUG: source gdf columns
# Index(['LINK_ID', 'ROUTE_SYS', 'ST_CONCAT', 'geometry'], dtype='object')
# 2020-05-27 12:09:31, DEBUG: source ShSt rename_variables_for_dbf columns
# Index(['shstReferenceId', 'shstGeometryId', 'shstFromIntersectionId',
#        'shstToIntersectionId', 'gisReferenceId', 'gisGeometryId',
#        'gisTotalSegments', 'gisSegmentIndex', 'gisFromIntersectionId',
#        'gisToIntersectionId', 'startSideOfStreet', 'endSideOfStreet',
#        'sideOfStreet', 'score', 'matchType', 'pp_link_id', 'geometry'],
#       dtype='object')
# 2020-05-27 12:09:31, DEBUG: source gdf columns
# Index(['OBJECTID', 'WISLR_OVLY', 'SURF_TYCD', 'TRLNS_SURF', 'TRLNS_SU_1',
#        'LSHD_SURF_', 'LEFT_SHLD_', 'RSHD_SURF_', 'RGHT_SHLD_', 'RDWY_OWRST',
#        'RW_INDC', 'RW_WD', 'MEDN_TYCD', 'LEFT_CURB_', 'RGHT_CURB_',
#        'PRKG_TYCD', 'TRLNS_NB', 'WISLR_SFRT', 'SDWK_TYCD', 'HARST_TYCD',
#        'VARST_TYCD', 'RDWY_MAGMT', 'RDWY_MAG_1', 'LOC_WISLR_', 'RWCRT_MILG',
#        'RDWY_CTGY_', 'RDWY_SBCTG', 'AVG_DLY_TR', 'AVG_DLY__1', 'AVG_DLY__2',
#        'RDWY_ACS_T', 'FED_URLC_T', 'FEDUA_TYCD', 'FED_CLSN_T', 'FNCT_CLS_T',
#        'NHS_CLS_TY', 'NHS_RTE_NB', 'HPMS_SMPL_', 'HOV_LANE_T', 'PVMT_IRI_N',
#        'PVMT_IRI_Y', 'ST_LABL_NM', 'ST_PRMY_SY', 'RDWY_LINK_', 'SHC_NTWK_N',
#        'WISLR_PTY_', 'WISLR_PTY1', 'WISLR_CMTY', 'WISLR_CERT', 'DOT_CNTY_C',
#        'LOC_FLKOS_', 'LOC_TLKOS_', 'LINK_OVLY_', 'DIR_INDC', 'OPOS_RDWY_',
#        'INV_YR', 'LOC_WI_CMT', 'MEDN_WD_MS', 'RDWY_SBML_', 'RDWY_GTRST',
#        'RDWY_HTRST', 'RDWY_MNTNR', 'RDWY_OWNR_', 'RDWY_SLRST', 'RDWY_WDRST',
#        'RDWY_WTRST', 'RWCRT_PTY_', 'RDWY_CERT_', 'RWSR_SYS_T', 'RDWY_SURF_',
#        'CSTMS_SFRT', 'RDWY_RTG_D', 'CNTY_PRMY_', 'DSGND_TRK_', 'DSGND_TRK1',
#        'CTFR_INDC', 'FNCT_CLS_C', 'FNCT_CLS_G', 'HPMS_SMPL1', 'WISLR_PT_1',
#        'SEG_WISLR_', 'RWCRT_RTE_', 'ASGD_RTE_I', 'ASGD_RTE_S', 'SFRTG_TYCD',
#        'RTG_SURF_T', 'TRADS_ID', 'PA_WISLR_P', 'WISLR_PT_2', 'PMRC_TYCD',
#        'DOT_RGN_NB', 'FED_SFGRP_', 'TRMT_TYID', 'MNTC_TRMT_', 'MNTC_TRMT1',
#        'MNTC_TRM_1', 'SHAPE_Leng', 'geometry', 'LINK_ID'],
#       dtype='object')
# 2020-05-27 12:11:31, INFO: Finished calculating assignment group variable: assign_group
# 2020-05-27 12:11:33, INFO: Calculating Roadway Class
# 2020-05-27 12:11:40, INFO: Finished calculating roadway class variable: roadway_class
# 2020-05-27 12:11:40, INFO: Adding Counts
# 2020-05-27 12:11:40, DEBUG: Adding MNDOT Counts using
# - shst file: D:\lasso\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# - shp file: AADT_mn
# - as network variable: AADT
# 2020-05-27 12:11:40, INFO: Adding Variable AADT using Shared Streets Reference from D:\lasso\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# 2020-05-27 12:11:46, INFO: Added variable: AADT using Shared Streets Reference
# 2020-05-27 12:11:47, DEBUG: Adding WiDot Counts using
# - shst file: D:\lasso\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# - shp file: AADT_wi
# - as network variable: AADT
# 2020-05-27 12:11:47, INFO: Adding Variable AADT using Shared Streets Reference from D:\lasso\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# 2020-05-27 12:11:56, INFO: Added variable: AADT using Shared Streets Reference
# d:\lasso\lasso\roadway.py:934: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ].astype(network_var_type)
# 2020-05-27 12:11:56, INFO: Finished adding counts variable: AADT
# 2020-05-27 12:11:56, INFO: Finished creating ML lanes variable: ML_lanes
# 2020-05-27 12:11:56, INFO: Hov corridor Variable 'segment_id' already in network. Returning without overwriting.
# 2020-05-27 12:11:56, INFO: Managed Variable 'managed' already in network. Returning without overwriting.
# 2020-05-27 12:11:56, INFO: Overwriting existing distance Variable 'distance' already in network
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# 2020-05-27 12:12:49, INFO: Calculating distance for centroid connectors
# 2020-05-27 12:12:56, INFO: Filling nan for network from network wrangler
# 2020-05-27 12:13:38, INFO: Converting variable type to MetCouncil standard
# 2020-05-27 12:13:38, INFO: Splitting variables by time period and category
# 2020-05-27 12:14:30, INFO: Setting Coordinate Reference System to EPSG 26915
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
#model_road_net.links_metcouncil_df.query('lanes == 0 & drive_access == 1 & centroidconnect')

# %%
#pd.options.display.max_columns = None
#model_road_net.links_metcouncil_df[model_road_net.links_metcouncil_df["model_link_id"] == 1390975]["segment_id"]

# %%
#model_road_net.links_metcouncil_df[model_road_net.links_metcouncil_df.model_link_id.isin([390975])]

# %%
#model_road_net.links_metcouncil_df.segment_id.value_counts()
pd.crosstab(model_road_net.links_metcouncil_df.segment_id, model_road_net.links_metcouncil_df.managed)
# Out:
# managed           0  1
# segment_id
# 0           1134083  0
# 5                 9  9

# %%
#model_road_net.links_metcouncil_df.plot("lanes_AM")

# %% [markdown]
# ## Export to shapefile
#
# As a last step, the network can be exported to a shapefile and paired CSVs after removing extraneous variables.
#
# (note that this step will also run the `roadway_standard_to_met_council_network()` method but I wanted to show it to you piecewise)

# %%
model_road_net.write_roadway_as_shp(
    output_link_shp = "C:/projects/met_council_git/data/interim/networks/fixed_width/link.shp",
    output_node_shp = "C:/projects/met_council_git/data/interim/networks/fixed_width/node.shp"
)
# Out:
# 2020-05-27 12:17:01, INFO: Writing Network as Shapefile
# 2020-05-27 12:17:01, DEBUG: Output Variables:
#  - model_link_id
#  - link_id
#  - A
#  - B
#  - shstGeometryId
#  - distance
#  - roadway
#  - name
#  - roadway_class
#  - bike_access
#  - walk_access
#  - drive_access
#  - truck_access
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - price_sov_AM
#  - price_hov2_AM
#  - price_hov3_AM
#  - price_truck_AM
#  - price_sov_MD
#  - price_hov2_MD
#  - price_hov3_MD
#  - price_truck_MD
#  - price_sov_PM
#  - price_hov2_PM
#  - price_hov3_PM
#  - price_truck_PM
#  - price_sov_NT
#  - price_hov2_NT
#  - price_hov3_NT
#  - price_truck_NT
#  - roadway_class_idx
#  - assign_group
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
#  - mpo
#  - area_type
#  - county
#  - centroidconnect
#  - AADT
#  - count_year
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - model_node_id
#  - N
#  - osm_node_id
#  - bike_node
#  - transit_node
#  - walk_node
#  - drive_node
#  - geometry
#  - X
#  - Y
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - segment_id
#  - managed
#  - bus_only
#  - rail_only
# 2020-05-27 12:17:01, DEBUG: Network Link Variables:
#  - A
#  - B
#  - HOV
#  - access
#  - bike_access
#  - bike_facility
#  - bridge
#  - bus_only
#  - distance
#  - drive_access
#  - egress
#  - geometry
#  - lanes
#  - locationReferences
#  - managed
#  - max_speed
#  - model_link_id
#  - name
#  - osm_link_id
#  - price
#  - rail_only
#  - ref
#  - roadway
#  - segment_id
#  - shstGeometryId
#  - shstReferenceId
#  - trn_priority
#  - truck_access
#  - ttime_assert
#  - tunnel
#  - u
#  - v
#  - walk_access
#  - width
#  - area_type
#  - county
#  - centroidconnect
#  - mpo
#  - assign_group
#  - roadway_class
#  - AADT
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - count_year
#  - ML_lanes
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - price_sov_AM
#  - price_hov2_AM
#  - price_hov3_AM
#  - price_truck_AM
#  - price_sov_MD
#  - price_hov2_MD
#  - price_hov3_MD
#  - price_truck_MD
#  - price_sov_PM
#  - price_hov2_PM
#  - price_hov3_PM
#  - price_truck_PM
#  - price_sov_NT
#  - price_hov2_NT
#  - price_hov3_NT
#  - price_truck_NT
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
# 2020-05-27 12:17:01, DEBUG: Network Node Variables:
#  - N
#  - osm_node_id
#  - shstReferenceId
#  - drive_node
#  - walk_node
#  - bike_node
#  - bus_only
#  - rail_only
#  - outboundReferenceIds
#  - inboundReferenceIds
#  - geometry
#  - x
#  - y
#  - X
#  - Y
# 2020-05-27 12:17:01, INFO: Renaming DBF Node Variables
# 2020-05-27 12:17:01, INFO: Renaming variables so that they are DBF-safe
# 2020-05-27 12:17:01, DEBUG: Variable crosswalk: D:\lasso\examples\settings\net_to_dbf.csv
#                  net         dbf
# 0     model_link_id     link_id
# 1    shstGeometryId       geoId
# 2     roadway_class     rdclass
# 3     bike_facility    bike_fac
# 4       bike_access        bike
# 5    transit_access     transit
# 6       walk_access        walk
# 7      drive_access       drive
# 8      truck_access       truck
# 9   trn_priority_AM       tp_AM
# 10  trn_priority_MD       tp_MD
# 11  trn_priority_PM       tp_PM
# 12  trn_priority_NT       tp_NT
# 13  ttime_assert_AM      tta_AM
# 14  ttime_assert_MD      tta_MD
# 15  ttime_assert_PM      tta_PM
# 16  ttime_assert_NT      tta_NT
# 17     price_sov_AM    P_SOV_AM
# 18    price_hov2_AM   P_HOV2_AM
# 19    price_hov3_AM   P_HOV3_AM
# 20   price_truck_AM    P_TRK_AM
# 21     price_sov_MD    P_SOV_MD
# 22    price_hov2_MD   P_HOV2_MD
# 23    price_hov3_MD   P_HOV3_MD
# 24   price_truck_MD    P_TRK_MD
# 25     price_sov_PM    P_SOV_PM
# 26    price_hov2_PM   P_HOV2_PM
# 27    price_hov3_PM   P_HOV3_PM
# 28   price_truck_PM    P_TRK_PM
# 29     price_sov_NT    P_SOV_NT
# 30    price_hov2_NT   P_HOV2_NT
# 31    price_hov3_NT   P_HOV3_NT
# 32   price_truck_NT    P_TRK_NT
# 33   road_class_idx  rdclass_ix
# 34     assign_group    assgngrp
# 35  centroidconnect    centroid
# 36      count_daily   count_day
# 37    model_node_id     node_id
# 38      osm_node_id   osmnodeid
# 39     transit_node   tran_node
# 2020-05-27 12:17:10, DEBUG: DBF Variables: N,osmnodeid,drive_node,walk_node,bike_node,bus_only,rail_only,geometry,X,Y,X,Y
# 2020-05-27 12:17:10, INFO: Renaming DBF Link Variables
# 2020-05-27 12:17:10, INFO: Renaming variables so that they are DBF-safe
# 2020-05-27 12:17:10, DEBUG: Variable crosswalk: D:\lasso\examples\settings\net_to_dbf.csv
#                  net         dbf
# 0     model_link_id     link_id
# 1    shstGeometryId       geoId
# 2     roadway_class     rdclass
# 3     bike_facility    bike_fac
# 4       bike_access        bike
# 5    transit_access     transit
# 6       walk_access        walk
# 7      drive_access       drive
# 8      truck_access       truck
# 9   trn_priority_AM       tp_AM
# 10  trn_priority_MD       tp_MD
# 11  trn_priority_PM       tp_PM
# 12  trn_priority_NT       tp_NT
# 13  ttime_assert_AM      tta_AM
# 14  ttime_assert_MD      tta_MD
# 15  ttime_assert_PM      tta_PM
# 16  ttime_assert_NT      tta_NT
# 17     price_sov_AM    P_SOV_AM
# 18    price_hov2_AM   P_HOV2_AM
# 19    price_hov3_AM   P_HOV3_AM
# 20   price_truck_AM    P_TRK_AM
# 21     price_sov_MD    P_SOV_MD
# 22    price_hov2_MD   P_HOV2_MD
# 23    price_hov3_MD   P_HOV3_MD
# 24   price_truck_MD    P_TRK_MD
# 25     price_sov_PM    P_SOV_PM
# 26    price_hov2_PM   P_HOV2_PM
# 27    price_hov3_PM   P_HOV3_PM
# 28   price_truck_PM    P_TRK_PM
# 29     price_sov_NT    P_SOV_NT
# 30    price_hov2_NT   P_HOV2_NT
# 31    price_hov3_NT   P_HOV3_NT
# 32   price_truck_NT    P_TRK_NT
# 33   road_class_idx  rdclass_ix
# 34     assign_group    assgngrp
# 35  centroidconnect    centroid
# 36      count_daily   count_day
# 37    model_node_id     node_id
# 38      osm_node_id   osmnodeid
# 39     transit_node   tran_node
# 2020-05-27 12:17:11, DEBUG: DBF Variables: A,B,geometry
# 2020-05-27 12:17:12, INFO: Writing Node Shapes:
#  - C:/projects/met_council_git/data/interim/networks/fixed_width/node.shp
# 2020-05-27 12:18:15, INFO: Writing Link Shapes:
#  - C:/projects/met_council_git/data/interim/networks/fixed_width/link.shp
# 2020-05-27 12:20:47, INFO: Writing Network Data to CSVs:
#  - D:\lasso\tests\scratch\links.csv
#  - D:\lasso\tests\scratch\nodes.csv

# %% [markdown]
# # Export to fixed width file

# %%
model_road_net.write_roadway_as_fixedwidth(
    output_link_txt = "C:/projects/met_council_git/data/interim/networks/fixed_width/link.txt",
    output_node_txt = "C:/projects/met_council_git/data/interim/networks/fixed_width/node.txt",
    output_link_header_width_txt = "C:/projects/met_council_git/data/interim/networks/fixed_width/link_header.csv",
    output_node_header_width_txt = "C:/projects/met_council_git/data/interim/networks/fixed_width/node_header.csv",
    output_cube_network_script = "C:/projects/met_council_git/data/interim/networks/fixed_width/make_complete_network_from_fixed_width_file.s"
)
# Out:
# 2020-05-27 12:23:22, DEBUG: Network Link Variables:
#  - A
#  - B
#  - HOV
#  - access
#  - bike_access
#  - bike_facility
#  - bridge
#  - bus_only
#  - distance
#  - drive_access
#  - egress
#  - geometry
#  - lanes
#  - locationReferences
#  - managed
#  - max_speed
#  - model_link_id
#  - name
#  - osm_link_id
#  - price
#  - rail_only
#  - ref
#  - roadway
#  - segment_id
#  - shstGeometryId
#  - shstReferenceId
#  - trn_priority
#  - truck_access
#  - ttime_assert
#  - tunnel
#  - u
#  - v
#  - walk_access
#  - width
#  - area_type
#  - county
#  - centroidconnect
#  - mpo
#  - assign_group
#  - roadway_class
#  - AADT
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - count_year
#  - ML_lanes
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - price_sov_AM
#  - price_hov2_AM
#  - price_hov3_AM
#  - price_truck_AM
#  - price_sov_MD
#  - price_hov2_MD
#  - price_hov3_MD
#  - price_truck_MD
#  - price_sov_PM
#  - price_hov2_PM
#  - price_hov3_PM
#  - price_truck_PM
#  - price_sov_NT
#  - price_hov2_NT
#  - price_hov3_NT
#  - price_truck_NT
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
# 2020-05-27 12:23:22, DEBUG: Network Node Variables:
#  - N
#  - osm_node_id
#  - shstReferenceId
#  - drive_node
#  - walk_node
#  - bike_node
#  - bus_only
#  - rail_only
#  - outboundReferenceIds
#  - inboundReferenceIds
#  - geometry
#  - x
#  - y
#  - X
#  - Y
# 2020-05-27 12:23:22, INFO: Starting fixed width convertion
# 2020-05-27 13:08:42, INFO: Writing out link database
# 2020-05-27 13:09:06, INFO: Writing out link header and width ----
# 2020-05-27 13:09:06, INFO: Starting fixed width convertion
# 2020-05-27 13:10:53, INFO: Writing out node database
# 2020-05-27 13:10:55, INFO: Writing out node header and width

# %% [markdown]
# # Write out as MetCouncil Model Transit Network
#
# Similar to the roadway network, the first step is to convert it to a Lasso object, and then write it to a cube line file.  Optionally, you could also export it to a shapefile to inspect using other means.

# %%
#standard_transit = StandardTransit.fromTransitNetwork(my_scenario.transit_net)
#standard_transit.feed

# %% [markdown]
# Write out the StandardTransit Lasso object to a cube line file:

# %%
#standard_transit.write_as_cube_lin()
