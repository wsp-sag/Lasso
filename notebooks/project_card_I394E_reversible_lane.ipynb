# %% [markdown]
# # I394E Reversible Lane Project Card

# %%
import os
import sys

from lasso import Project
from lasso import CubeTransit
from network_wrangler import WranglerLogger

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
logger = logging.getLogger("WranglerLogger")
logger.handlers[0].stream = sys.stdout
# if you don't want to see so much detail, set to logging.INFO or DEBUG
logger.setLevel(logging.DEBUG)

# %%
#set examples directory
INTERIM_DIR = "C:\\projects\\met_council_git\\data\\interim"
INTERIM_DIR
# Out:
# 'C:\\projects\\met_council_git\\data\\interim'

# %% [markdown]
# ## Roadway Project Card
#
# Roadway project cards are built by reading in a base network in the standard network format and a then processing cube log files.
#
# The log file information is stored in a dataframe called `roadway_changes`
#
# The project card data is created when comparing log file to the base network and is  stored in the variable `card_data`

# %%
i394e_roadway_project = Project.create_project(
        base_roadway_dir=os.path.join(INTERIM_DIR,"networks", "base_network"),
        roadway_log_file=os.path.join(INTERIM_DIR,"change_logs","i394_reversible_lanes.log")
    )
# Out:
# 2020-05-22 09:48:56, INFO: No base transit network.
# 2020-05-22 09:48:56, INFO: No transit changes given or processed.
# 2020-05-22 09:48:56, INFO: Reading logfile: C:\projects\met_council_git\data\interim\change_logs\i394_reversible_lanes.log
# 2020-05-22 09:48:56, INFO: Processed 0 Node lines and 24 Link lines
# 2020-05-22 09:48:56, INFO: Reading from following files:
# -C:\projects\met_council_git\data\interim\networks\base_network\link.json
# -C:\projects\met_council_git\data\interim\networks\base_network\node.geojson
# -C:\projects\met_council_git\data\interim\networks\base_network\shape.geojson.
# 2020-05-22 09:53:14, INFO: Read 1134074 links from C:\projects\met_council_git\data\interim\networks\base_network\link.json
# 2020-05-22 09:53:14, INFO: Read 354346 nodes from C:\projects\met_council_git\data\interim\networks\base_network\node.geojson
# 2020-05-22 09:53:14, INFO: Read 1134074 shapes from C:\projects\met_council_git\data\interim\networks\base_network\shape.geojson
# 2020-05-22 10:04:06, INFO: Lasso base directory set as: D:\lasso
# 2020-05-22 10:04:06, INFO: Creating calculated roadway variables.
# 2020-05-22 10:04:06, INFO: Calculating Area Type from Spatial Data and adding as roadway network variable: area_type
# 2020-05-22 10:04:19, DEBUG: Reading Area Type Shapefile D:\lasso\metcouncil_data\area_type\ThriveMSP2040CommunityDesignation.shp
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(4326 != {'init': 'epsg:4326', 'no_defs': True})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# 2020-05-22 10:05:55, DEBUG: Area Type Codes Used: {23: 4, 24: 3, 25: 2, 35: 2, 36: 1, 41: 1, 51: 1, 52: 1, 53: 1, 60: 1}
# 2020-05-22 10:05:55, INFO: Finished Calculating Area Type from Spatial Data into variable: area_type
# 2020-05-22 10:05:58, INFO: Adding roadway network variable for county using a spatial join with: D:\lasso\metcouncil_data\county\cb_2017_us_county_5m.shp
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# C:\Anaconda3\envs\lasso_env\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(4326 != {'init': 'epsg:4326', 'no_defs': True})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# 2020-05-22 10:07:45, INFO: Finished Calculating county variable: county
# 2020-05-22 10:07:48, INFO: Calculating Centroid Connector and adding as roadway network variable: centroidconnect
# 2020-05-22 10:07:48, DEBUG: Calculating Centroid Connectors using highest TAZ number: 3100
# 2020-05-22 10:07:48, INFO: Finished calculating centroid connector variable: centroidconnect
# 2020-05-22 10:07:48, INFO: Calculating MPO as roadway network variable: mpo
# 2020-05-22 10:07:48, DEBUG: MPO Counties: [,1,,, ,3,,, ,4,,, ,5,,, ,6,,, ,7,,, ,2,]
# 2020-05-22 10:07:48, INFO: Finished calculating MPO variable: mpo
# 2020-05-22 10:07:48, INFO: Calculating Assignment Group as network variable: assign_group
# 2020-05-22 10:07:48, DEBUG: Calculating Centroid Connectors
# 2020-05-22 10:07:48, INFO: Centroid Connector Variable 'centroidconnect' already in network. Returning without overwriting.
# 2020-05-22 10:07:48, DEBUG: Reading MRCC / Shared Streets Match CSV
# 2020-05-22 10:07:48, DEBUG: Reading MRCC Shapefile: D:\lasso\metcouncil_data\mrcc\trans_mrcc_centerlines.shp
# 2020-05-22 10:07:55, DEBUG: MRCC GDF Columns
# Index(['LINK_ID', 'ROUTE_SYS', 'ST_CONCAT', 'geometry'], dtype='object')
# 2020-05-22 10:07:56, DEBUG: mrcc shst ref df columns
# Index(['shstReferenceId', 'shstGeometryId', 'pp_link_id', 'score'], dtype='object')
# 2020-05-22 10:08:04, DEBUG: WiDOT GDF Columns
# Index(['OBJECTID', 'WISLR_OVLY', 'SURF_TYCD', 'TRLNS_SURF', 'TRLNS_SU_1',
#        'LSHD_SURF_', 'LEFT_SHLD_', 'RSHD_SURF_', 'RGHT_SHLD_', 'RDWY_OWRST',
#        'RW_INDC', 'RW_WD', 'MEDN_TYCD', 'LEFT_CURB_', 'RGHT_CURB_',
#        'PRKG_TYCD', 'TRLNS_NB', 'WISLR_SFRT', 'SDWK_TYCD', 'HARST_TYCD',
#        'VARST_TYCD', 'RDWY_MAGMT', 'RDWY_MAG_1', 'LOC_WISLR_', 'RWCRT_MILG',
#        'RDWY_CTGY_', 'RDWY_SBCTG', 'AVG_DLY_TR', 'AVG_DLY__1', 'AVG_DLY__2',
#        'RDWY_ACS_T', 'FED_URLC_T', 'FEDUA_TYCD', 'FED_CLSN_T', 'FNCT_CLS_T',
#        'NHS_CLS_TY', 'NHS_RTE_NB', 'HPMS_SMPL_', 'HOV_LANE_T', 'PVMT_IRI_N',
#        'PVMT_IRI_Y', 'ST_LABL_NM', 'ST_PRMY_SY', 'RDWY_LINK_', 'SHC_NTWK_N',
#        'WISLR_PTY_', 'WISLR_PTY1', 'WISLR_CMTY', 'WISLR_CERT', 'DOT_CNTY_C',
#        'LOC_FLKOS_', 'LOC_TLKOS_', 'LINK_OVLY_', 'DIR_INDC', 'OPOS_RDWY_',
#        'INV_YR', 'LOC_WI_CMT', 'MEDN_WD_MS', 'RDWY_SBML_', 'RDWY_GTRST',
#        'RDWY_HTRST', 'RDWY_MNTNR', 'RDWY_OWNR_', 'RDWY_SLRST', 'RDWY_WDRST',
#        'RDWY_WTRST', 'RWCRT_PTY_', 'RDWY_CERT_', 'RWSR_SYS_T', 'RDWY_SURF_',
#        'CSTMS_SFRT', 'RDWY_RTG_D', 'CNTY_PRMY_', 'DSGND_TRK_', 'DSGND_TRK1',
#        'CTFR_INDC', 'FNCT_CLS_C', 'FNCT_CLS_G', 'HPMS_SMPL1', 'WISLR_PT_1',
#        'SEG_WISLR_', 'RWCRT_RTE_', 'ASGD_RTE_I', 'ASGD_RTE_S', 'SFRTG_TYCD',
#        'RTG_SURF_T', 'TRADS_ID', 'PA_WISLR_P', 'WISLR_PT_2', 'PMRC_TYCD',
#        'DOT_RGN_NB', 'FED_SFGRP_', 'TRMT_TYID', 'MNTC_TRMT_', 'MNTC_TRMT1',
#        'MNTC_TRM_1', 'SHAPE_Leng', 'geometry', 'LINK_ID'],
#       dtype='object')
# 2020-05-22 10:08:22, DEBUG: widot shst ref df columns
# 2020-05-22 10:08:22, DEBUG: source ShSt rename_variables_for_dbf columns
# Index(['shstReferenceId', 'shstGeometryId', 'pp_link_id', 'score'], dtype='object')
# 2020-05-22 10:08:22, DEBUG: source gdf columns
# Index(['LINK_ID', 'ROUTE_SYS', 'ST_CONCAT', 'geometry'], dtype='object')
# 2020-05-22 10:08:40, DEBUG: source ShSt rename_variables_for_dbf columns
# Index(['shstReferenceId', 'shstGeometryId', 'shstFromIntersectionId',
#        'shstToIntersectionId', 'gisReferenceId', 'gisGeometryId',
#        'gisTotalSegments', 'gisSegmentIndex', 'gisFromIntersectionId',
#        'gisToIntersectionId', 'startSideOfStreet', 'endSideOfStreet',
#        'sideOfStreet', 'score', 'matchType', 'pp_link_id', 'geometry'],
#       dtype='object')
# 2020-05-22 10:08:40, DEBUG: source gdf columns
# Index(['OBJECTID', 'WISLR_OVLY', 'SURF_TYCD', 'TRLNS_SURF', 'TRLNS_SU_1',
#        'LSHD_SURF_', 'LEFT_SHLD_', 'RSHD_SURF_', 'RGHT_SHLD_', 'RDWY_OWRST',
#        'RW_INDC', 'RW_WD', 'MEDN_TYCD', 'LEFT_CURB_', 'RGHT_CURB_',
#        'PRKG_TYCD', 'TRLNS_NB', 'WISLR_SFRT', 'SDWK_TYCD', 'HARST_TYCD',
#        'VARST_TYCD', 'RDWY_MAGMT', 'RDWY_MAG_1', 'LOC_WISLR_', 'RWCRT_MILG',
#        'RDWY_CTGY_', 'RDWY_SBCTG', 'AVG_DLY_TR', 'AVG_DLY__1', 'AVG_DLY__2',
#        'RDWY_ACS_T', 'FED_URLC_T', 'FEDUA_TYCD', 'FED_CLSN_T', 'FNCT_CLS_T',
#        'NHS_CLS_TY', 'NHS_RTE_NB', 'HPMS_SMPL_', 'HOV_LANE_T', 'PVMT_IRI_N',
#        'PVMT_IRI_Y', 'ST_LABL_NM', 'ST_PRMY_SY', 'RDWY_LINK_', 'SHC_NTWK_N',
#        'WISLR_PTY_', 'WISLR_PTY1', 'WISLR_CMTY', 'WISLR_CERT', 'DOT_CNTY_C',
#        'LOC_FLKOS_', 'LOC_TLKOS_', 'LINK_OVLY_', 'DIR_INDC', 'OPOS_RDWY_',
#        'INV_YR', 'LOC_WI_CMT', 'MEDN_WD_MS', 'RDWY_SBML_', 'RDWY_GTRST',
#        'RDWY_HTRST', 'RDWY_MNTNR', 'RDWY_OWNR_', 'RDWY_SLRST', 'RDWY_WDRST',
#        'RDWY_WTRST', 'RWCRT_PTY_', 'RDWY_CERT_', 'RWSR_SYS_T', 'RDWY_SURF_',
#        'CSTMS_SFRT', 'RDWY_RTG_D', 'CNTY_PRMY_', 'DSGND_TRK_', 'DSGND_TRK1',
#        'CTFR_INDC', 'FNCT_CLS_C', 'FNCT_CLS_G', 'HPMS_SMPL1', 'WISLR_PT_1',
#        'SEG_WISLR_', 'RWCRT_RTE_', 'ASGD_RTE_I', 'ASGD_RTE_S', 'SFRTG_TYCD',
#        'RTG_SURF_T', 'TRADS_ID', 'PA_WISLR_P', 'WISLR_PT_2', 'PMRC_TYCD',
#        'DOT_RGN_NB', 'FED_SFGRP_', 'TRMT_TYID', 'MNTC_TRMT_', 'MNTC_TRMT1',
#        'MNTC_TRM_1', 'SHAPE_Leng', 'geometry', 'LINK_ID'],
#       dtype='object')
# 2020-05-22 10:10:20, INFO: Finished calculating assignment group variable: assign_group
# 2020-05-22 10:10:21, INFO: Calculating Roadway Class
# 2020-05-22 10:10:25, INFO: Finished calculating roadway class variable: roadway_class
# 2020-05-22 10:10:26, INFO: Adding Counts
# 2020-05-22 10:10:26, DEBUG: Adding MNDOT Counts using
# - shst file: D:\lasso\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# - shp file: AADT_mn
# - as network variable: AADT
# 2020-05-22 10:10:26, INFO: Adding Variable AADT using Shared Streets Reference from D:\lasso\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# 2020-05-22 10:10:30, INFO: Added variable: AADT using Shared Streets Reference
# 2020-05-22 10:10:31, DEBUG: Adding WiDot Counts using
# - shst file: D:\lasso\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# - shp file: AADT_wi
# - as network variable: AADT
# 2020-05-22 10:10:31, INFO: Adding Variable AADT using Shared Streets Reference from D:\lasso\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# 2020-05-22 10:10:36, INFO: Added variable: AADT using Shared Streets Reference
# d:\lasso\lasso\roadway.py:934: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ].astype(network_var_type)
# 2020-05-22 10:10:37, INFO: Finished adding counts variable: AADT
# 2020-05-22 10:10:37, INFO: Finished creating ML lanes variable: ML_lanes
# 2020-05-22 10:10:37, INFO: Finished creating hov corridor variable: segment_id
# 2020-05-22 10:10:37, INFO: Finished creating managed variable: managed
# 2020-05-22 10:10:37, INFO: Overwriting existing distance Variable 'distance' already in network
# C:\Anaconda3\envs\lasso_env\lib\site-packages\pyproj\crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# 2020-05-22 10:11:23, INFO: Calculating distance for centroid connectors
# 2020-05-22 10:11:29, INFO: Filling nan for network from network wrangler
# 2020-05-22 10:11:59, INFO: Converting variable type to MetCouncil standard
# 2020-05-22 10:12:40, INFO: Lasso base directory set as: D:\lasso
# 2020-05-22 10:12:40, INFO: Evaluating compatibility between roadway network changes and base network. Not evaluating deletions.
# 2020-05-22 10:12:46, INFO: Evaluating project changes.
# 2020-05-22 10:12:46, DEBUG: Processing link deletions
# 2020-05-22 10:12:46, DEBUG: 0 Links Deleted.
# 2020-05-22 10:12:46, DEBUG: Processing link additions
# 2020-05-22 10:12:46, DEBUG: 0 Links Added
# 2020-05-22 10:12:46, DEBUG: No Nodes Added
# 2020-05-22 10:12:46, DEBUG: Processing changes
# 2020-05-22 10:12:47, DEBUG: 17 Changes Processed

# %%
i394e_roadway_project.roadway_changes.columns
# Out:
# Index(['OBJECT', 'OPERATION', 'GROUP', 'A', 'B', 'bike_access', 'bus_only',
#        'distance', 'drive_access', 'managed', 'model_link_id', 'name',
#        'rail_only', 'roadway', 'segment_id', 'shstGeometryId', 'truck_access',
#        'walk_access', 'area_type', 'county', 'centroidconnect', 'mpo',
#        'assign_group', 'roadway_class', 'AADT', 'count_AM', 'count_MD',
#        'count_PM', 'count_NT', 'count_daily', 'count_year', 'trn_priority_AM',
#        'trn_priority_MD', 'trn_priority_PM', 'trn_priority_NT',
#        'ttime_assert_AM', 'ttime_assert_MD', 'ttime_assert_PM',
#        'ttime_assert_NT', 'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_NT',
#        'ML_lanes_AM', 'ML_lanes_MD', 'ML_lanes_PM', 'ML_lanes_NT',
#        'price_sov_AM', 'price_hov2_AM', 'price_hov3_AM', 'price_truck_AM',
#        'price_sov_MD', 'price_hov2_MD', 'price_hov3_MD', 'price_truck_MD',
#        'price_sov_PM', 'price_hov2_PM', 'price_hov3_PM', 'price_truck_PM',
#        'price_sov_NT', 'price_hov2_NT', 'price_hov3_NT', 'price_truck_NT',
#        'access_AM', 'access_MD', 'access_PM', 'access_NT', 'RCI', 'LANES',
#        'LINKCLASS', 'SPEED', 'CAPACITY', 'TIME', 'AMCAP', 'OFFCAP', 'PMCAP',
#        'NEWVOLAM', 'CONGAM', 'NEWVOLMD', 'CONGMD', 'SEGMENT_IDY',
#        'model_node_id', 'osm_node_id', 'drive_node', 'walk_node', 'bike_node',
#        'X', 'Y'],
#       dtype='object')

# %%
i394e_roadway_project.roadway_changes
# Out:
#    OBJECT OPERATION GROUP       A       B bike_access bus_only distance  \
# 0       L         C     0   92628   95168           0        0   1.5974
# 1       L         C     0   95168   92628           0        0   1.5974
# 2       L         C     1  161372  161394           0        0    0.499
# 3       L         C     2  161394  113416           0        0   0.2228
# 4       L         C     0    7177   95168           0        0   0.3219
# 5       L         C     0   95168    7177           0        0   0.3219
# 6       L         C     1    7177  162799           0        0   0.0764
# 7       L         C     2  162799  155509           0        0   0.3581
# 8       L         C     0  162799   38333           0        0   0.2917
# 9       L         C     1    7144   38333           0        0   0.3815
# 10      L         C     2    7144   38333           0        0   0.3815
# 11      L         C     0  113416    7144           0        0   0.3412
# 12      L         C     1    9311  161372           0        0   0.7335
# 13      L         C     2   53723    9311           0        0   0.3329
# 14      L         C     0   97783   53723           0        0   0.7071
# 15      L         C     1   53558   97783           0        0   0.3925
# 16      L         C     2   53554   53558           0        0   0.1769
# 17      L         C     0   97783  149053           0        0   0.2144
# 18      L         C     1   93855  149053           0        0   0.4927
# 19      L         C     1  149053   93855           0        0   0.4927
# 20      L         C     2   92628   93855           0        0   0.2171
# 21      L         C     2   93855   92628           0        0   0.2171
# 22      L         C     0   92628   95168           0        0   1.5974
# 23      L         C     0   95168   92628           0        0   1.5974
#
#    drive_access managed  ... NEWVOLMD CONGMD SEGMENT_IDY model_node_id  \
# 0             1       1  ...        0      0           0           NaN
# 1             1       0  ...        0      0           0           NaN
# 2             1       0  ...        0      0           0           NaN
# 3             1       0  ...        0      0           0           NaN
# 4             1       1  ...        0      0           0           NaN
# 5             1       1  ...        0      0           0           NaN
# 6             1       1  ...        0      0           0           NaN
# 7             1       1  ...        0      0           0           NaN
# 8             1       1  ...        0      0           0           NaN
# 9             1       5  ...        0      0           0           NaN
# 10            1       0  ...        0      0           0           NaN
# 11            1       0  ...        0      0           0           NaN
# 12            1       0  ...        0      0           0           NaN
# 13            1       0  ...        0      0           0           NaN
# 14            1       0  ...        0      0           0           NaN
# 15            1       0  ...        0      0           0           NaN
# 16            1       0  ...        0      0           0           NaN
# 17            1       1  ...        0      0           0           NaN
# 18            1       1  ...        0      0           0           NaN
# 19            1       1  ...        0      0           0           NaN
# 20            1       1  ...        0      0           0           NaN
# 21            1       1  ...        0      0           0           NaN
# 22            1       1  ...        0      0           0           NaN
# 23            1       1  ...        0      0           0           NaN
#
#    osm_node_id drive_node walk_node bike_node    X    Y
# 0          NaN        NaN       NaN       NaN  NaN  NaN
# 1          NaN        NaN       NaN       NaN  NaN  NaN
# 2          NaN        NaN       NaN       NaN  NaN  NaN
# 3          NaN        NaN       NaN       NaN  NaN  NaN
# 4          NaN        NaN       NaN       NaN  NaN  NaN
# 5          NaN        NaN       NaN       NaN  NaN  NaN
# 6          NaN        NaN       NaN       NaN  NaN  NaN
# 7          NaN        NaN       NaN       NaN  NaN  NaN
# 8          NaN        NaN       NaN       NaN  NaN  NaN
# 9          NaN        NaN       NaN       NaN  NaN  NaN
# 10         NaN        NaN       NaN       NaN  NaN  NaN
# 11         NaN        NaN       NaN       NaN  NaN  NaN
# 12         NaN        NaN       NaN       NaN  NaN  NaN
# 13         NaN        NaN       NaN       NaN  NaN  NaN
# 14         NaN        NaN       NaN       NaN  NaN  NaN
# 15         NaN        NaN       NaN       NaN  NaN  NaN
# 16         NaN        NaN       NaN       NaN  NaN  NaN
# 17         NaN        NaN       NaN       NaN  NaN  NaN
# 18         NaN        NaN       NaN       NaN  NaN  NaN
# 19         NaN        NaN       NaN       NaN  NaN  NaN
# 20         NaN        NaN       NaN       NaN  NaN  NaN
# 21         NaN        NaN       NaN       NaN  NaN  NaN
# 22         NaN        NaN       NaN       NaN  NaN  NaN
# 23         NaN        NaN       NaN       NaN  NaN  NaN
#
# [24 rows x 88 columns]

# %%
i394e_roadway_project.write_project_card(
        os.path.join(INTERIM_DIR,"project_cards", "i394_reversible_managed_lane.yml")
    )
# Out:
# 2020-05-22 10:12:47, INFO: Wrote project card to: C:\projects\met_council_git\data\interim\project_cards\i394_reversible_managed_lane.yml
